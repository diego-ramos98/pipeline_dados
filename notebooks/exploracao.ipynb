# %% [markdown]
# ***LENDO OS DADOS***

# %%
import pandas as pd

# %%
path_json = '../data_raw/dados_empresaA.json'
path_csv = '../data_raw/dados_empresaB.csv'

# %%
df_data_json = pd.read_json(path_json)
df_data_csv = pd.read_csv(path_csv)

# %%
df_data_json.head()
# Out:
#         Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 0           Blush em pó     Eletrodomésticos                  79.41
# 1  Lápis de sobrancelha     Eletrodomésticos                  85.47
# 2          Base líquida               Roupas                  75.02
# 3          Base líquida               Roupas                  44.94
# 4  Lápis de sobrancelha            Alimentos                  58.63
#
#    Quantidade em Estoque     Filial
# 0                      7   Filial 7
# 1                     78   Filial 8
# 2                     34   Filial 8
# 3                     90  Filial 10
# 4                     91   Filial 7

# %%
df_data_csv.head()
# Out:
#            Nome do Item Classificação do Produto  Valor em Reais (R$)  \
# 0  Lápis de sobrancelha                   Roupas                55.17
# 1           Batom matte              Eletrônicos                74.15
# 2             Corretivo                   Roupas                54.86
# 3    Delineador líquido                   Roupas                91.29
# 4         Batom líquido                   Roupas                44.65
#
#    Quantidade em Estoque Nome da Loja               Data da Venda
# 0                     62     Filial 1  2023-04-13 18:58:06.794203
# 1                     48     Filial 9  2023-06-03 18:58:06.794203
# 2                     36     Filial 5  2023-06-08 18:58:06.794203
# 3                      1     Filial 8  2023-02-27 18:58:06.794203
# 4                     52     Filial 2  2022-09-05 18:58:06.794203

# %% [markdown]
# ***CONFERINDO NOMES E TAMANHO DAS COLUNAS***

# %%
nome_colunas_json = df_data_json.columns
nome_colunas_json
# Out:
# pandas.core.indexes.base.Index

# %%
nomes_colunas_csv = df_data_csv.columns
nomes_colunas_csv
# Out:
# Index(['Nome do Item', 'Classificação do Produto', 'Valor em Reais (R$)',
#        'Quantidade em Estoque', 'Nome da Loja', 'Data da Venda'],
#       dtype='object')

# %%
len(nome_colunas_json)
# Out:
# 5

# %%
len(nomes_colunas_csv)
# Out:
# 6

# %% [markdown]
# ***DELETANDO COLUNA***

# %%
df_data_csv= df_data_csv.drop(columns=['Data da Venda'])

# %%
df_data_csv
# Out:
#               Nome do Item Classificação do Produto  Valor em Reais (R$)  \
# 0     Lápis de sobrancelha                   Roupas                55.17
# 1              Batom matte              Eletrônicos                74.15
# 2                Corretivo                   Roupas                54.86
# 3       Delineador líquido                   Roupas                91.29
# 4            Batom líquido                   Roupas                44.65
# ...                    ...                      ...                  ...
# 1318  Lápis de sobrancelha                Alimentos                94.08
# 1319             Corretivo                   Roupas                 5.60
# 1320           Pó compacto              Eletrônicos                22.36
# 1321          Base líquida                   Roupas                 3.79
# 1322       Sombra de olhos              Eletrônicos                41.73
#
#       Quantidade em Estoque Nome da Loja
# 0                        62     Filial 1
# ...

# %% [markdown]
# ***RENOMEANDO COLUNA***

# %%
df_data_csv = df_data_csv.rename(columns={"Nome do Item": "Nome do Produto","Classificação do Produto": "Categoria do Produto","Valor em Reais (R$)": "Preço do Produto (R$)","Nome da Loja": "Filial"})

# %%
df_data_csv
# Out:
#            Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 0     Lápis de sobrancelha               Roupas                  55.17
# 1              Batom matte          Eletrônicos                  74.15
# 2                Corretivo               Roupas                  54.86
# 3       Delineador líquido               Roupas                  91.29
# 4            Batom líquido               Roupas                  44.65
# ...                    ...                  ...                    ...
# 1318  Lápis de sobrancelha            Alimentos                  94.08
# 1319             Corretivo               Roupas                   5.60
# 1320           Pó compacto          Eletrônicos                  22.36
# 1321          Base líquida               Roupas                   3.79
# 1322       Sombra de olhos          Eletrônicos                  41.73
#
#       Quantidade em Estoque    Filial
# 0                        62  Filial 1
# ...

# %% [markdown]
# ***JUNTANDO DATAFRAMES***

# %%
len(df_data_csv) + len(df_data_json)
# Out:
# 4446

# %%
list_df= [df_data_json,df_data_csv]

# %%
df_data_csv_concat_json = pd.concat(list_df)

# %%
df_data_csv_concat_json
# Out:
#            Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 0              Blush em pó     Eletrodomésticos                  79.41
# 1     Lápis de sobrancelha     Eletrodomésticos                  85.47
# 2             Base líquida               Roupas                  75.02
# 3             Base líquida               Roupas                  44.94
# 4     Lápis de sobrancelha            Alimentos                  58.63
# ...                    ...                  ...                    ...
# 1318  Lápis de sobrancelha            Alimentos                  94.08
# 1319             Corretivo               Roupas                   5.60
# 1320           Pó compacto          Eletrônicos                  22.36
# 1321          Base líquida               Roupas                   3.79
# 1322       Sombra de olhos          Eletrônicos                  41.73
#
#       Quantidade em Estoque     Filial
# 0                         7   Filial 7
# ...

# %% [markdown]
# ***CONFERINDO SE EXISTE DUPLICADA***

# %%
sum(df_data_csv_concat_json.duplicated())
# Out:
# 0

# %%
df_data_csv_concat_json.drop_duplicates()
# Out:
#            Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 0              Blush em pó     Eletrodomésticos                  79.41
# 1     Lápis de sobrancelha     Eletrodomésticos                  85.47
# 2             Base líquida               Roupas                  75.02
# 3             Base líquida               Roupas                  44.94
# 4     Lápis de sobrancelha            Alimentos                  58.63
# ...                    ...                  ...                    ...
# 1318  Lápis de sobrancelha            Alimentos                  94.08
# 1319             Corretivo               Roupas                   5.60
# 1320           Pó compacto          Eletrônicos                  22.36
# 1321          Base líquida               Roupas                   3.79
# 1322       Sombra de olhos          Eletrônicos                  41.73
#
#       Quantidade em Estoque     Filial
# 0                         7   Filial 7
# ...

# %% [markdown]
# ***CONFERINDO SE EXISTE DADOS NULOS***

# %%
print(df_data_csv_concat_json.isnull())
# Out:
#       Nome do Produto  Categoria do Produto  Preço do Produto (R$)  \
# 0               False                 False                  False
# 1               False                 False                  False
# 2               False                 False                  False
# 3               False                 False                  False
# 4               False                 False                  False
# ...               ...                   ...                    ...
# 1318            False                 False                  False
# 1319            False                 False                  False
# 1320            False                 False                  False
# 1321            False                 False                  False
# 1322            False                 False                  False
#
#       Quantidade em Estoque  Filial
# 0                     False   False
# 1                     False   False
# 2                     False   False
# ...

# %%
df_data_csv_concat_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4446 entries, 0 to 1322
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nome do Produto        4446 non-null   object
#  1   Categoria do Produto   4446 non-null   object
#  2   Preço do Produto (R$)  4446 non-null   float64
#  3   Quantidade em Estoque  4446 non-null   int64
#  4   Filial                 4446 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 208.4+ KB

# %%
df_data_csv_concat_json.dropna()
# Out:
#            Nome do Produto Categoria do Produto  Preço do Produto (R$)  \
# 0              Blush em pó     Eletrodomésticos                  79.41
# 1     Lápis de sobrancelha     Eletrodomésticos                  85.47
# 2             Base líquida               Roupas                  75.02
# 3             Base líquida               Roupas                  44.94
# 4     Lápis de sobrancelha            Alimentos                  58.63
# ...                    ...                  ...                    ...
# 1318  Lápis de sobrancelha            Alimentos                  94.08
# 1319             Corretivo               Roupas                   5.60
# 1320           Pó compacto          Eletrônicos                  22.36
# 1321          Base líquida               Roupas                   3.79
# 1322       Sombra de olhos          Eletrônicos                  41.73
#
#       Quantidade em Estoque     Filial
# 0                         7   Filial 7
# ...

# %% [markdown]
# ***CRIANDO CSV DOS DADOS JUNTOS***

# %%
df_data_csv_concat_json.to_csv("../data_processed/dados_lojas_juntas.csv")

# %%
type(df_data_csv_concat_json)
# Out:
# pandas.core.frame.DataFrame
